# %%
# добавления пути до модуля spin_nn
import sys
import os

project_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_path not in sys.path:
    sys.path.append(project_path)

# %% [markdown]
# ## Визуализация результатов

# %%
from spin_nn.model import MSKModel
from spin_nn.utils import load_mnist
from spin_nn.training import train
from spin_nn.visualization import *

import pandas as pd
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

# %%
json_path = "/Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs/metrics.json"

metrics = load_metrics(json_path)
plot_metrics(metrics)

# %%
visualize_layer_weights(
    weights_folder="/Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs",
    layer_index=2,
    step=10
)
# Out:
# Weights and structure loaded from /Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs/weights_epoch_10.json
# Weights and structure loaded from /Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs/weights_epoch_100.json
# Weights and structure loaded from /Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs/weights_epoch_20.json
# Weights and structure loaded from /Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs/weights_epoch_30.json
# Weights and structure loaded from /Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs/weights_epoch_40.json
# Weights and structure loaded from /Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs/weights_epoch_50.json
# Weights and structure loaded from /Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs/weights_epoch_60.json
# ...

# %%
X_train, X_test, y_train, y_test = load_mnist()
if isinstance(X_train, pd.DataFrame):
    X_train = X_train.to_numpy()
if isinstance(X_test, pd.DataFrame):
    X_test = X_test.to_numpy()

X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
test_image = X_test[0]

# %%
model = MSKModel.load_weights("/Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs/weights_epoch_10.json")
# Out:
# Weights and structure loaded from /Users/rknzhl/projects/spin_glass/code/data/20241219_143047_epochs/weights_epoch_10.json

# %%
visualize_spins_from_model(model, test_image, layer_index=0)
